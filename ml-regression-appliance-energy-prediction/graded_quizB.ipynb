# %% [markdown]
# ## This answers Questions 12 to 20, in the Stage-B Assessment.

# %% [markdown]
# ### Import the important libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Load the dataset

# %%
energy_data = pd.read_csv("energydata_complete.csv")
energy_data.head() #Let's have a peek
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %% [markdown]
# ### Descriptive Information and Summary

# %%
#Check for info about dataset

energy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %% [markdown]
# So no null values.

# %% [markdown]
# Summary Statistics

# %%
energy_data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %% [markdown]
# ### QUESTION 12

# %% [markdown]
# * From the dataset, fit a linear model on the relationship between the temperature in the living room in Celsius(x=T2) and the temperature outside the building (y=T6). What is the R^2 value in two d.p?

# %%
#Select the predictor

X = energy_data[['T2']]
X
# Out:
#               T2
# 0      19.200000
# 1      19.200000
# 2      19.200000
# 3      19.200000
# 4      19.200000
# ...          ...
# 19730  25.890000
# 19731  25.754000
# 19732  25.628571
# 19733  25.414000
# 19734  25.264286
#
# [19735 rows x 1 columns]

# %%
#Select the Target
y = energy_data[['T6']]
y
# Out:
#               T6
# 0       7.026667
# 1       6.833333
# 2       6.560000
# 3       6.433333
# 4       6.366667
# ...          ...
# 19730  24.796667
# 19731  24.196667
# 19732  23.626667
# 19733  22.433333
# 19734  21.026667
#
# [19735 rows x 1 columns]

# %% [markdown]
# ### Splitting our data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42)

# %%
#Importing and declaring our model
from sklearn.linear_model import LinearRegression

lin_model = LinearRegression()

#fit the model to the training dataset
lin_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#obtain predictions
predicted_values = lin_model.predict(X_test)

# %%
# import the r2 performance metric from sklearn 
from sklearn.metrics import r2_score

# Checking the R^2 value
r2_score = r2_score(y_test, predicted_values)

# Root mean square score to 2 decimal places
round(r2_score, 2)
# Out:
# 0.64

# %% [markdown]
# #### QUESTION 13

# %% [markdown]
# * Normalise the dataset using the MinMaxScaler after removing the following columns: ["date", "lights"]. The target variable is "Appliances". Use a 70-30 train-test set split with a random state of 42(for reprducibility). Run a multiple linear regression using the training set and evaluate your model on the test set. Answer the following questions.
#
# * What is the Mean Absolute Error in 2 d.p?

# %%
#Drop of the "date" and "lights" columns
energy_data_adj = energy_data.drop(["date", "lights"], axis=1)

# %%
#Import MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

norm_energy_data = pd.DataFrame(scaler.fit_transform(energy_data_adj), columns=energy_data_adj.columns)

norm_energy_data
# Out:
#        Appliances        T1      RH_1        T2      RH_2        T3      RH_3  \
# 0        0.046729  0.327350  0.566187  0.225345  0.684038  0.215188  0.746066
# 1        0.046729  0.327350  0.541326  0.225345  0.682140  0.215188  0.748871
# 2        0.037383  0.327350  0.530502  0.225345  0.679445  0.215188  0.755569
# 3        0.037383  0.327350  0.524080  0.225345  0.678414  0.215188  0.758685
# 4        0.046729  0.327350  0.531419  0.225345  0.676727  0.215188  0.758685
# ...           ...       ...       ...       ...       ...       ...       ...
# 19730    0.084112  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374
# 19731    0.074766  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178
# 19732    0.242991  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988
# 19733    0.383178  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294
# 19734    0.392523  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062
#
# ...

# %%
#Select our Predictor and Target

y = norm_energy_data[["Appliances"]]
X = norm_energy_data.drop("Appliances", axis=1)

X
# Out:
#              T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0      0.327350  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1      0.327350  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2      0.327350  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3      0.327350  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4      0.327350  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
# ...         ...       ...       ...       ...       ...       ...       ...
# 19730  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374  0.864865
# 19731  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178  0.864865
# 19732  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988  0.864865
# 19733  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294  0.864865
# 19734  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062  0.864865
#
# ...

# %%
#Split into training and testing set

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state=42)

# %%
#Train a Linear reg model
linear_reg = LinearRegression()

#fit the model to the training dataset
linear_reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Get predicted values

predicted_values = linear_reg.predict(X_test)

# %%
#Import all metrics needed
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ### Mean Absolute Error

# %%
mae = mean_absolute_error(y_test, predicted_values)

#Mean Absolute Error to 2 d.p
round(mae, 2)
# Out:
# 0.05

# %% [markdown]
# ### QUESTION 14

# %% [markdown]
# ### Residual Sum of Squares

# %%
rss = np.sum(np.square(y_test - predicted_values))

# Residual Sum of Squares to 2 d.p

round(rss, 2)
# Out:
# Appliances    45.35
# dtype: float64

# %% [markdown]
# ### QUESTION 15

# %% [markdown]
# ### Root Mean Squared Error

# %%
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))

#Root Mean Squared Error to 3 d.p
round(rmse, 3)
# Out:
# 0.088

# %% [markdown]
# ### QUESTION 16

# %% [markdown]
# ### Coefficient of Determination or R Squared Error

# %%
r2_score = r2_score(y_test, predicted_values)

#R Squared Error
round(r2_score, 2)
# Out:
# 0.15

# %% [markdown]
# ### QUESTION 17: Features Weights

# %%
weights = pd.Series(linear_reg.coef_[0], index= X_train.columns).sort_values()
weights
# Out:
# RH_2          -0.456698
# T_out         -0.321860
# T2            -0.236178
# T9            -0.189941
# RH_8          -0.157595
# RH_out        -0.077671
# RH_7          -0.044614
# RH_9          -0.039800
# T5            -0.015657
# T1            -0.003281
# rv1            0.000770
# rv2            0.000770
# Press_mm_hg    0.006839
# T7             0.010319
# Visibility     0.012307
# RH_5           0.016006
# RH_4           0.026386
# T4             0.028981
# Windspeed      0.029183
# RH_6           0.038049
# RH_3           0.096048
# T8             0.101995
# Tdewpoint      0.117758
# T6             0.236425
# T3             0.290627
# RH_1           0.553547
# dtype: float64

# %% [markdown]
# RH2, RH1 are the highest and lowest respectively

# %% [markdown]
# ### QUESTION 18: Ridge Regression model

# %% [markdown]
# * Train a ridge regression model with an alpha value of 0.4. Is there any change to the root mean squared error (RMSE) when evaluated on the test set?

# %%
# import ridge from sklearn

from sklearn.linear_model import Ridge

ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.4, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
# predicting using ridge model with test data

y_ridge_predict = ridge_reg.predict(X_test)
y_ridge_predict
# Out:
# array([[0.03321872],
#        [0.24043824],
#        [0.03461337],
#        ...,
#        [0.06872351],
#        [0.10025536],
#        [0.05851175]])

# %%
# Evaluating the ridge model through 
# RMSE

RMSE = np.sqrt(mean_squared_error(y_test,y_ridge_predict))
round(RMSE, 3)
# Out:
# 0.088

# %% [markdown]
# The RMSE of the ridge regression model is the same as the RMSE of the linear regression model

# %% [markdown]
# ### QUESTION 19:

# %% [markdown]
# * Train a lasso regression model with an alpha value of 0.001 and obtain the new feature weights with it. How many of the features have non-zero feature weights?

# %%
# import lasso from sklearn

from sklearn.linear_model import Lasso

# %%
# training the lasso model

lasso_reg = Lasso(alpha = 0.001)
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
# Obtaining the lasso model weights 

weights = pd.Series(lasso_reg.coef_, index= X_train.columns).sort_values()
weights
# Out:
# RH_out        -0.049557
# RH_8          -0.000110
# T1             0.000000
# Tdewpoint      0.000000
# Visibility     0.000000
# Press_mm_hg   -0.000000
# T_out          0.000000
# RH_9          -0.000000
# T9            -0.000000
# T8             0.000000
# RH_7          -0.000000
# rv1           -0.000000
# T7            -0.000000
# T6             0.000000
# RH_5           0.000000
# T5            -0.000000
# RH_4           0.000000
# T4            -0.000000
# RH_3           0.000000
# T3             0.000000
# RH_2          -0.000000
# T2             0.000000
# RH_6          -0.000000
# rv2           -0.000000
# Windspeed      0.002912
# RH_1           0.017880
# dtype: float64

# %% [markdown]
# From the above, there are only 4 features with non zero:
# 1. RH_out  2. RH_8
# 3. Windspeed
# 4. RH_1

# %% [markdown]
# ### QUESTION 20

# %% [markdown]
# * What is the new RMSE with lasso regression? in 3 d.p

# %%
# Predicting using the Lasso reg model 

lasso_predict = lasso_reg.predict(X_test)
lasso_predict
# Out:
# array([0.07370267, 0.08143458, 0.07716072, ..., 0.07792848, 0.09034412,
#        0.08359255])

# %%
#Calculating RMSE 

RMSE = np.sqrt(mean_squared_error(y_test,lasso_predict))
round(RMSE, 3)
# Out:
# 0.094

# %% [markdown]
# the RMSE of the lasso model is: 0.094
